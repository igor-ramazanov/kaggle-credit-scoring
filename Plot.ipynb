# %%
import matplotlib.pyplot as pt
import pandas as pd

# %%
data = []
for i in range(2, 30):
    data.append(pd.read_csv("res/plot/plot_%d.csv" % i))

# %%
pt.plot(data[4].FPR, data[4].TPR, data[26].FPR, data[26].TPR)
pt.ylim([0,1])
pt.show()
